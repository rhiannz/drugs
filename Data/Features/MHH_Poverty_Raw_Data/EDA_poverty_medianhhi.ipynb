# %%
import pandas as pd

# %%
saipe_99 = pd.read_fwf('est99all.txt', header=None)[[0, 1, 2, 5, 20]]
saipe_99 = saipe_99.rename(columns={0: 'StateFIPS', 1: 'CountyFIPS', 2: 'PovertyCount', 5: 'PovertyPercentage', 20: 'MedianHHI'})

saipe_00 = pd.read_fwf('est00all.txt', header=None)[[0, 1, 2, 5, 20]]
saipe_00 = saipe_00.rename(columns={0: 'StateFIPS', 1: 'CountyFIPS', 2: 'PovertyCount', 5: 'PovertyPercentage', 20: 'MedianHHI'})

saipe_01 = pd.read_fwf('est01all.txt', header=None)[[0, 1, 2, 5, 20]]
saipe_01 = saipe_01.rename(columns={0: 'StateFIPS', 1: 'CountyFIPS', 2: 'PovertyCount', 5: 'PovertyPercentage', 20: 'MedianHHI'})

saipe_02 = pd.read_fwf('est02all.txt', header=None)[[0, 1, 2, 5, 20]]
saipe_02 = saipe_02.rename(columns={0: 'StateFIPS', 1: 'CountyFIPS', 2: 'PovertyCount', 5: 'PovertyPercentage', 20: 'MedianHHI'})

# %%
saipe_99['Year'] = [1999] * len(saipe_99)
saipe_99 = saipe_99[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_00['Year'] = [2000] * len(saipe_00)
saipe_00 = saipe_00[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_01['Year'] = [2001] * len(saipe_01)
saipe_01 = saipe_01[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_02['Year'] = [2002] * len(saipe_02)
saipe_02 = saipe_02[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

# %%
saipe_03 = pd.read_excel('est03all.xls', header=1).rename(columns={'State FIPS': 'StateFIPS', 'County FIPS': 'CountyFIPS',
                                                        'Poverty Estimate All Ages': 'PovertyCount',
                                                        'Poverty Percent All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_03['Year'] = [2003] * len(saipe_03)
saipe_03 = saipe_03[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_04 = pd.read_excel('est04all.xls', header=1).rename(columns={'State FIPS': 'StateFIPS', 'County FIPS': 'CountyFIPS',
                                                        'Poverty Estimate All Ages': 'PovertyCount',
                                                        'Poverty Percent All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_04['Year'] = [2004] * len(saipe_04)
saipe_04 = saipe_04[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_05 = pd.read_excel('est05all.xls', header=2).rename(columns={'State FIPS': 'StateFIPS', 'County FIPS': 'CountyFIPS',
                                                        'Poverty Estimate All Ages': 'PovertyCount',
                                                        'Poverty Percent All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_05['Year'] = [2005] * len(saipe_05)
saipe_05 = saipe_05[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_06 = pd.read_excel('est06all.xls', header=2).rename(columns={'State FIPS': 'StateFIPS', 'County FIPS': 'CountyFIPS',
                                                        'Poverty Estimate All Ages': 'PovertyCount',
                                                        'Poverty Percent All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_06['Year'] = [2006] * len(saipe_06)
saipe_06 = saipe_06[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_07 = pd.read_excel('est07all.xls', header=2).rename(columns={'State FIPS': 'StateFIPS', 'County FIPS': 'CountyFIPS',
                                                        'Poverty Estimate All Ages': 'PovertyCount',
                                                        'Poverty Percent All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_07['Year'] = [2007] * len(saipe_07)
saipe_07 = saipe_07[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_08 = pd.read_excel('est08all.xls', header=2).rename(columns={'State FIPS': 'StateFIPS', 'County FIPS': 'CountyFIPS',
                                                        'Poverty Estimate All Ages': 'PovertyCount',
                                                        'Poverty Percent All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_08['Year'] = [2008] * len(saipe_08)
saipe_08 = saipe_08[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_09 = pd.read_excel('est09all.xls', header=2).rename(columns={'State FIPS': 'StateFIPS', 'County FIPS': 'CountyFIPS',
                                                        'Poverty Estimate All Ages': 'PovertyCount',
                                                        'Poverty Percent All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_09['Year'] = [2009] * len(saipe_09)
saipe_09 = saipe_09[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_10 = pd.read_excel('est10all.xls', header=2).rename(columns={'State FIPS': 'StateFIPS', 'County FIPS': 'CountyFIPS',
                                                        'Poverty Estimate All Ages': 'PovertyCount',
                                                        'Poverty Percent All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_10['Year'] = [2010] * len(saipe_10)
saipe_10 = saipe_10[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_11 = pd.read_excel('est11all.xls', header=2).rename(columns={'State FIPS': 'StateFIPS', 'County FIPS': 'CountyFIPS',
                                                        'Poverty Estimate All Ages': 'PovertyCount',
                                                        'Poverty Percent All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_11['Year'] = [2011] * len(saipe_11)
saipe_11 = saipe_11[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_12 = pd.read_excel('est12all.xls', header=2).rename(columns={'State FIPS Code': 'StateFIPS',
                                                                   'County FIPS Code': 'CountyFIPS',
                                                        'Poverty Estimate, All Ages': 'PovertyCount',
                                                        'Poverty Percent, All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_12['Year'] = [2012] * len(saipe_12)
saipe_12 = saipe_12[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

# %%
saipe_13 = pd.read_excel('est13all.xls', header=3).rename(columns={'State FIPS Code': 'StateFIPS',
                                                                   'County FIPS Code': 'CountyFIPS',
                                                        'Poverty Estimate, All Ages': 'PovertyCount',
                                                        'Poverty Percent, All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_13['Year'] = [2013] * len(saipe_13)
saipe_13 = saipe_13[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_14 = pd.read_excel('est14all.xls', header=3).rename(columns={'State FIPS Code': 'StateFIPS',
                                                                   'County FIPS Code': 'CountyFIPS',
                                                        'Poverty Estimate, All Ages': 'PovertyCount',
                                                        'Poverty Percent, All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_14['Year'] = [2014] * len(saipe_14)
saipe_14 = saipe_14[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_15 = pd.read_excel('est15all.xls', header=3).rename(columns={'State FIPS Code': 'StateFIPS',
                                                                   'County FIPS Code': 'CountyFIPS',
                                                        'Poverty Estimate, All Ages': 'PovertyCount',
                                                        'Poverty Percent, All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_15['Year'] = [2015] * len(saipe_15)
saipe_15 = saipe_15[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_16 = pd.read_excel('est16all.xls', header=3).rename(columns={'State FIPS Code': 'StateFIPS',
                                                                   'County FIPS Code': 'CountyFIPS',
                                                        'Poverty Estimate, All Ages': 'PovertyCount',
                                                        'Poverty Percent, All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_16['Year'] = [2016] * len(saipe_16)
saipe_16 = saipe_16[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_17 = pd.read_excel('est17all.xls', header=3).rename(columns={'State FIPS Code': 'StateFIPS',
                                                                   'County FIPS Code': 'CountyFIPS',
                                                        'Poverty Estimate, All Ages': 'PovertyCount',
                                                        'Poverty Percent, All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_17['Year'] = [2017] * len(saipe_17)
saipe_17 = saipe_17[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_18 = pd.read_excel('est18all.xls', header=3).rename(columns={'State FIPS Code': 'StateFIPS',
                                                                   'County FIPS Code': 'CountyFIPS',
                                                        'Poverty Estimate, All Ages': 'PovertyCount',
                                                        'Poverty Percent, All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_18['Year'] = [2018] * len(saipe_18)
saipe_18 = saipe_18[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_19 = pd.read_excel('est19all.xls', header=3).rename(columns={'State FIPS Code': 'StateFIPS',
                                                                   'County FIPS Code': 'CountyFIPS',
                                                        'Poverty Estimate, All Ages': 'PovertyCount',
                                                        'Poverty Percent, All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_19['Year'] = [2019] * len(saipe_19)
saipe_19 = saipe_19[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

saipe_20 = pd.read_excel('est20all.xls', header=3).rename(columns={'State FIPS Code': 'StateFIPS',
                                                                   'County FIPS Code': 'CountyFIPS',
                                                        'Poverty Estimate, All Ages': 'PovertyCount',
                                                        'Poverty Percent, All Ages' :'PovertyPercentage',
                                                        'Median Household Income': 'MedianHHI'})
saipe_20['Year'] = [2020] * len(saipe_20)
saipe_20 = saipe_20[['Year', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage', 'MedianHHI']]

# %%
saipe_list = [saipe_99, saipe_00, saipe_01, saipe_02, saipe_03, saipe_04, saipe_05, saipe_06, saipe_07, saipe_08, saipe_09,
         saipe_10, saipe_11, saipe_12, saipe_13, saipe_14, saipe_15, saipe_16, saipe_17, saipe_18, saipe_19, saipe_20 ]  # List of your dataframes
saipe_df = pd.concat(saipe_list)
saipe_df = saipe_df.dropna(subset=['CountyFIPS'])

# %%
saipe_df['CountyFIPS'] = saipe_df['CountyFIPS'].astype(int)
saipe_df['CountyFIPS'] = saipe_df['CountyFIPS'].astype(str)
saipe_df['CountyFIPS'] = saipe_df['CountyFIPS'].str.zfill(3)
saipe_df['StateFIPS'] = saipe_df['StateFIPS'].astype(str).str.zfill(2)

# %%
saipe_df['FIPS'] = saipe_df['StateFIPS'] + saipe_df['CountyFIPS']
saipe_df = saipe_df[['Year', 'FIPS', 'StateFIPS', 'CountyFIPS', 'PovertyCount', 'PovertyPercentage',
       'MedianHHI']]

# %%
saipe_df
# Out:
#       Year   FIPS StateFIPS CountyFIPS PovertyCount PovertyPercentage  \
# 0     1999  00000        00        000     32791272              11.9
# 1     1999  01000        01        000       667468              15.3
# 2     1999  01001        01        001         4991              11.4
# 3     1999  01003        01        003        14668              10.5
# 4     1999  01005        01        005         5903              22.3
# ...    ...    ...       ...        ...          ...               ...
# 3190  2020  56037        56        037         3187               7.6
# 3191  2020  56039        56        039         1207               5.2
# 3192  2020  56041        56        041         1697               8.5
# 3193  2020  56043        56        043          739               9.7
# 3194  2020  56045        56        045          679              10.6
#
#      MedianHHI
# 0        40696
# 1        33840
# 2        39702
# 3        39194
# 4        25837
# ...        ...
# ...

# %%
saipe_df.to_csv('saipe_99_20.csv')
