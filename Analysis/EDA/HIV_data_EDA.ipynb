# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir(os.path.dirname(os.getcwd()))
os.chdir(os.path.dirname(os.getcwd()))
os.chdir('Data')

# %%
df = pd.read_csv('hiv_county_data.csv', skiprows = 12)
df.head()
# Out:
#              Unnamed: 0            Cases  Rate per 100000          Cases.1  \
# 0  Abbeville County, SC  Data suppressed  Data suppressed  Data suppressed
# 1     Acadia Parish, LA                5             10.4               10
# 2   Accomack County, VA  Data suppressed  Data suppressed  Data suppressed
# 3        Ada County, ID                9              2.9               17
# 4      Adair County, IA                0              0.0                0
#
#   Rate per 100000.1          Cases.2 Rate per 100000.2          Cases.3  \
# 0   Data suppressed  Data suppressed   Data suppressed  Data suppressed
# 1              20.8                9              18.1                7
# 2   Data suppressed                0               0.0  Data suppressed
# 3               5.5               19               6.0               22
# 4               0.0                0               0.0                0
#
#   Rate per 100000.3          Cases.4  ...          Cases.9 Rate per 100000.9  \
# 0   Data suppressed  Data suppressed  ...                0               0.0
# 1              14.1  Data suppressed  ...                6              11.8
# 2   Data suppressed  Data suppressed  ...  Data suppressed   Data suppressed
# 3               6.8               18  ...               17               4.5
# 4               0.0                0  ...                0               0.0
#
#           Cases.10 Rate per 100000.10         Cases.11 Rate per 100000.11  \
# 0  Data suppressed    Data suppressed                0                0.0
# 1                9               17.8  Data suppressed    Data suppressed
# 2  Data suppressed    Data suppressed  Data suppressed    Data suppressed
# 3               13                3.3               12                3.0
# 4                0                0.0  Data suppressed    Data suppressed
#
#           Cases.12  Rate per 100000.12         Cases.13  Rate per 100000.13
# 0  Data suppressed     Data suppressed  Data suppressed     Data suppressed
# 1  Data suppressed     Data suppressed                6  Data not available
# 2  Data suppressed     Data suppressed  Data suppressed     Data suppressed
# 3               17  Data not available               12  Data not available
# 4                0  Data not available                0  Data not available
#
# [5 rows x 29 columns]
